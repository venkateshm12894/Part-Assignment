# %% [markdown]
# ### **STRING CONCATENATION**

# %%
##Write a Python program that takes two strings,and concatenates them together. Display the concatenated string as the output.
Output = "Hello" +" "+ "Venkatesh"
print(Output)
# Out:
# Hello Venkatesh

# %%
##Now, concatenate string 3, "Welcome to Python programming,” to the existing string and display the output string
output = "Hello" +" "+ "Venkatesh" +" "+ "Welcome to Python Programming"
print(output)
# Out:
# Hello Venkatesh Welcome to Python Programming

# %% [markdown]
# # **STRING SLICING AND INDEXING:**

# %%
## Print first character of above string
output[0:1]
# Out:
# 'H'

# %%
##print last character of above string
output[44:]
# Out:
# 'g'

# %%
##Print the first 5 characters of the string.
output[0:6]
# Out:
# 'Hello '

# %%
##Print the last 11 characters of the string.
output[34:]
# Out:
# 'Programming'

# %%
##Print the string in reverse.
output[::-1]
# Out:
# 'gnimmargorP nohtyP ot emocleW hsetakneV olleH'

# %%
##Use slicing and print the word “Python” from the existing string.
output[27:33]
# Out:
# 'Python'

# %% [markdown]
# # **STRING METHODS**

# %%
##Convert the sentence to uppercase.
strM = "Python beginner tutorial"
strM.upper()
# Out:
# 'PYTHON BEGINNER TUTORIAL'

# %%
##Convert the sentence to lowercase.
strM.lower()
# Out:
# 'python beginner tutorial'

# %%
##Use Capitalize and return the sentence to the original input form.
strM.capitalize()
# Out:
# 'Python beginner tutorial'

# %%
##Count the total number of occurrences of character ‘t’ in the string.
strM.count('t')
# Out:
# 3

# %%
##Replace all occurrences of “Python” with “Data Analytics” in the input string
strM.replace('Python', 'Data Analytics')
# Out:
# 'Data Analytics beginner tutorial'

# %% [markdown]
# # **TUPLES (CREATION, MODIFICATION AND ACCESS)**

# %%
A = [10, 20, 30]
B = [40, 50, 60]

##Concatenate the two tuples and store it in “t_combine”
T_combine = A + B
print(T_combine)
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
##Repeat the elements of “t_combine” 3 times
T_combine * 3
# Out:
# [10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60]

# %%
##Access the 3rd element from “t_combine”
T_combine[2]
# Out:
# 30

# %%
##Access the first three elements from “t_combine”
T_combine[0:3]
# Out:
# [10, 20, 30]

# %%
##Access the last three elements from “t_combine”
T_combine[3:6]
# Out:
# [40, 50, 60]
